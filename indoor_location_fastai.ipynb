# %% [markdown]
# # Tabular example

# %%
from fastai import *          # Quick accesss to most common functionality
from fastai.tabular import *  # Quick accesss to tabular functionality     # Access to example data provided with fastai

# %% [markdown]
# Tabular data should be in a Pandas `DataFrame`.

# %%
path = Path("~/.fastai/data")
df = pd.read_csv(path/'sample_data.csv')

# %%
# Need a dummy categorical feature for the fastai APIs to work properly
df['cat_1'] = True

# %%
df.head()
# Out:
#    srs_1  srs_2  srs_3  srs_4  srs_5  srs_6  srs_7  srs_8  srs_9  srs_10  \
# 0    NaN   97.0    155    143     98    145    102    102    144     100
# 1   96.0   94.0    116     99     98    105     95    101    168     101
# 2   96.0  101.0    105    100     95     98     98     96    123      99
# 3   99.0   96.0    158    146     98    148     95     98    158      96
# 4  100.0  100.0    140    126     98    141    102    105    159      97
#
#    ...    srs_26  srs_27  srs_28  srs_29  srs_30  srs_31  srs_32  ue_loc_1  \
# 0  ...        99     112      94      98     100    96.0      95      rp12
# 1  ...       101     195     104      96      97    93.0      98      rp27
# 2  ...       103     108      97      99      98    97.0     192      rp32
# 3  ...       100     112      99      98      97    97.0      99      rp12
# 4  ...       106     109     106      98     102    99.0      99      rp12
#
#         ue_loc_2  cat_1
# 0  rp12:rp3:rp24   True
# 1  rp27:rp9:rp24   True
# 2  rp32:rp24:rp9   True
# 3   rp12:rp9:rp3   True
# 4  rp12:rp9:rp24   True
#
# [5 rows x 35 columns]

# %%
dep_var = 'ue_loc_1'
cat_names = ['cat_1']
cont_names = ['srs_1', 'srs_2', 'srs_3', 'srs_4', 'srs_5', 'srs_6', 'srs_7', 'srs_8', 'srs_9', 'srs_10', 'srs_11', 'srs_12', 'srs_13', 'srs_14', 'srs_15', 'srs_16', 'srs_17', 'srs_18', 'srs_19', 'srs_20', 'srs_21', 'srs_22', 'srs_23', 'srs_24', 'srs_25', 'srs_26', 'srs_27', 'srs_28', 'srs_29', 'srs_30', 'srs_31', 'srs_32']
procs = [FillMissing, Categorify, Normalize]

# %%
#test = TabularList.from_df(df.iloc[800:1000].copy(), path=path, cont_names=cont_names)

# %%
data = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
                           .random_split_by_pct(valid_pct=0.2, seed=42)
                           .label_from_df(cols=dep_var)
                           #.add_test(test, label=0)
                           .databunch())

# %%
data.show_batch(rows=10)
# Out:
# <table>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <col width='10px'>  <tr>
#     <th>cat_1</th>
#     <th>srs_1</th>
#     <th>srs_2</th>
#     <th>srs_3</th>
#     <th>srs_4</th>
#     <th>srs_5</th>
#     <th>srs_6</th>
#     <th>srs_7</th>
#     <th>srs_8</th>
#     <th>srs_9</th>
#     <th>srs_10</th>
#     <th>srs_11</th>
#     <th>srs_12</th>
#     <th>srs_13</th>
#     <th>srs_14</th>
#     <th>srs_15</th>
#     <th>srs_16</th>
#     <th>srs_17</th>
#     <th>srs_18</th>
#     <th>srs_19</th>
#     <th>srs_20</th>
#     <th>srs_21</th>
#     <th>srs_22</th>
#     <th>srs_23</th>
#     <th>srs_24</th>
#     <th>srs_25</th>
#     <th>srs_26</th>
#     <th>srs_27</th>
#     <th>srs_28</th>
#     <th>srs_29</th>
#     <th>srs_30</th>
#     <th>srs_31</th>
#     <th>srs_32</th>
#     <th>target</th>
#   </tr>
#   <tr>
#     <th>True</th>
#     <th>0.1744</th>
#     <th>-1.3583</th>
#     <th>-0.4208</th>
#     <th>0.2657</th>
#     <th>-1.0681</th>
#     <th>2.2320</th>
#     <th>1.2050</th>
#     <th>-0.0011</th>
#     <th>0.3985</th>
#     <th>1.3944</th>
#     <th>-0.3230</th>
#     <th>0.2407</th>
#     <th>-1.2252</th>
#     <th>-0.2793</th>
#     <th>-0.2424</th>
#     <th>0.4118</th>
#     <th>-1.3680</th>
#     <th>0.3869</th>
#     <th>0.0324</th>
#     <th>0.0571</th>
#     <th>-1.6128</th>
#     <th>-0.0710</th>
#     <th>0.2634</th>
#     <th>-0.3048</th>
#     <th>-0.7300</th>
#     <th>0.9741</th>
#     <th>-0.3259</th>
#     <th>0.1968</th>
#     <th>-1.1457</th>
#     <th>-0.3943</th>
#     <th>0.2500</th>
#     <th>-0.4798</th>
#     <th>rp6</th>
#   </tr>
#   <tr>
#     <th>True</th>
#     <th>-1.6848</th>
#     <th>-0.4480</th>
#     <th>-0.3396</th>
#     <th>0.1006</th>
#     <th>-1.0681</th>
#     <th>2.3080</th>
#     <th>-0.8403</th>
#     <th>0.4152</th>
#     <th>0.2044</th>
#     <th>0.9384</th>
#     <th>-0.7826</th>
#     <th>-0.0537</th>
#     <th>-0.3489</th>
#     <th>-0.6475</th>
#     <th>-0.0962</th>
#     <th>0.7788</th>
#     <th>-0.8737</th>
#     <th>0.8002</th>
#     <th>-0.4094</th>
#     <th>0.0571</th>
#     <th>-0.7513</th>
#     <th>-0.0710</th>
#     <th>0.2634</th>
#     <th>0.5671</th>
#     <th>0.9775</th>
#     <th>0.1322</th>
#     <th>-0.1772</th>
#     <th>-0.2524</th>
#     <th>0.2212</th>
#     <th>0.0532</th>
#     <th>-0.1899</th>
#     <th>-0.5382</th>
#     <th>rp6</th>
#   </tr>
#   <tr>
#     <th>True</th>
#     <th>-0.2904</th>
#     <th>-0.4480</th>
#     <th>-0.4208</th>
#     <th>-1.0546</th>
#     <th>-1.0681</th>
#     <th>-0.6193</th>
#     <th>-1.2494</th>
#     <th>-1.6662</th>
#     <th>-0.9598</th>
#     <th>0.0262</th>
#     <th>1.0557</th>
#     <th>-0.9369</th>
#     <th>0.5275</th>
#     <th>-0.2793</th>
#     <th>-0.3886</th>
#     <th>-0.7197</th>
#     <th>1.3505</th>
#     <th>-0.0264</th>
#     <th>-0.8511</th>
#     <th>0.0571</th>
#     <th>0.9717</th>
#     <th>-0.8254</th>
#     <th>-0.5855</th>
#     <th>0.4582</th>
#     <th>-0.3031</th>
#     <th>1.3951</th>
#     <th>2.0534</th>
#     <th>1.5445</th>
#     <th>-1.1457</th>
#     <th>0.5008</th>
#     <th>1.5696</th>
#     <th>-0.4215</th>
#     <th>rp27</th>
#   </tr>
#   <tr>
#     <th>True</th>
#     <th>-1.6848</th>
#     <th>0.4623</th>
#     <th>0.9609</th>
#     <th>0.8020</th>
#     <th>-0.1699</th>
#     <th>0.6353</th>
#     <th>1.2050</th>
#     <th>0.4152</th>
#     <th>1.1746</th>
#     <th>-0.8859</th>
#     <th>-2.1614</th>
#     <th>1.2465</th>
#     <th>0.9657</th>
#     <th>-0.2793</th>
#     <th>-0.3886</th>
#     <th>-0.0775</th>
#     <th>0.8562</th>
#     <th>2.4534</th>
#     <th>2.2413</th>
#     <th>0.9414</th>
#     <th>0.9717</th>
#     <th>-0.3225</th>
#     <th>0.1785</th>
#     <th>0.2402</th>
#     <th>-1.5838</th>
#     <th>0.9741</th>
#     <th>-0.3853</th>
#     <th>0.1968</th>
#     <th>0.6768</th>
#     <th>0.0532</th>
#     <th>-0.1899</th>
#     <th>-0.5382</th>
#     <th>rp12</th>
#   </tr>
#   <tr>
#     <th>True</th>
#     <th>-1.2200</th>
#     <th>0.4623</th>
#     <th>0.0262</th>
#     <th>-0.6008</th>
#     <th>3.4227</th>
#     <th>-0.5813</th>
#     <th>0.7960</th>
#     <th>3.3291</th>
#     <th>1.3202</th>
#     <th>0.0262</th>
#     <th>1.9749</th>
#     <th>-0.6180</th>
#     <th>2.7184</th>
#     <th>2.2982</th>
#     <th>-0.3886</th>
#     <th>-0.5668</th>
#     <th>3.0805</th>
#     <th>2.4534</th>
#     <th>2.6831</th>
#     <th>0.4993</th>
#     <th>0.5409</th>
#     <th>3.9525</th>
#     <th>1.6218</th>
#     <th>0.4582</th>
#     <th>1.4044</th>
#     <th>0.9741</th>
#     <th>1.9344</th>
#     <th>1.5445</th>
#     <th>0.2212</th>
#     <th>-0.8419</th>
#     <th>0.6899</th>
#     <th>-0.4507</th>
#     <th>rp27</th>
#   </tr>
#   <tr>
#     <th>True</th>
#     <th>0.6392</th>
#     <th>0.4623</th>
#     <th>0.9609</th>
#     <th>0.8433</th>
#     <th>0.2792</th>
#     <th>0.5972</th>
#     <th>-0.8403</th>
#     <th>-0.8336</th>
#     <th>-1.2024</th>
#     <th>1.3944</th>
#     <th>-1.7018</th>
#     <th>1.2710</th>
#     <th>-0.3489</th>
#     <th>-0.2793</th>
#     <th>-0.0962</th>
#     <th>-0.0775</th>
#     <th>-0.1323</th>
#     <th>-0.8530</th>
#     <th>0.0324</th>
#     <th>0.0571</th>
#     <th>-2.0435</th>
#     <th>-0.8254</th>
#     <th>-0.9251</th>
#     <th>0.1312</th>
#     <th>0.9775</th>
#     <th>-0.2888</th>
#     <th>-0.4448</th>
#     <th>-0.7016</th>
#     <th>2.0438</th>
#     <th>-0.3943</th>
#     <th>-1.0696</th>
#     <th>-0.5382</th>
#     <th>rp12</th>
#   </tr>
#   <tr>
#     <th>True</th>
#     <th>0.1744</th>
#     <th>0.4623</th>
#     <th>0.3107</th>
#     <th>0.1006</th>
#     <th>0.2792</th>
#     <th>0.3691</th>
#     <th>0.7960</th>
#     <th>0.8315</th>
#     <th>-1.2024</th>
#     <th>0.9384</th>
#     <th>1.5153</th>
#     <th>1.5163</th>
#     <th>0.9657</th>
#     <th>0.0889</th>
#     <th>-0.0232</th>
#     <th>-0.4445</th>
#     <th>-0.1323</th>
#     <th>1.6268</th>
#     <th>0.0324</th>
#     <th>0.0571</th>
#     <th>-0.3206</th>
#     <th>-0.3225</th>
#     <th>-1.3496</th>
#     <th>-1.6126</th>
#     <th>0.1238</th>
#     <th>-0.7098</th>
#     <th>-0.3556</th>
#     <th>-0.2524</th>
#     <th>0.2212</th>
#     <th>0.0532</th>
#     <th>1.1297</th>
#     <th>-0.4215</th>
#     <th>rp12</th>
#   </tr>
#   <tr>
#     <th>True</th>
#     <th>-0.7552</th>
#     <th>0.4623</th>
#     <th>-0.9898</th>
#     <th>0.6783</th>
#     <th>0.2792</th>
#     <th>0.5972</th>
#     <th>-2.4766</th>
#     <th>1.2477</th>
#     <th>0.4470</th>
#     <th>-0.4298</th>
#     <th>-1.7018</th>
#     <th>-0.4953</th>
#     <th>0.0893</th>
#     <th>-0.6475</th>
#     <th>-0.0962</th>
#     <th>2.5526</th>
#     <th>-0.6266</th>
#     <th>-0.0264</th>
#     <th>1.3578</th>
#     <th>0.0571</th>
#     <th>-0.7513</th>
#     <th>-0.5740</th>
#     <th>0.6030</th>
#     <th>-0.6317</th>
#     <th>-0.7300</th>
#     <th>0.9741</th>
#     <th>-0.6827</th>
#     <th>1.0953</th>
#     <th>-0.6901</th>
#     <th>-2.6322</th>
#     <th>-1.5095</th>
#     <th>-0.6548</th>
#     <th>rp16</th>
#   </tr>
#   <tr>
#     <th>True</th>
#     <th>0.1744</th>
#     <th>1.3726</th>
#     <th>-1.1523</th>
#     <th>-0.0231</th>
#     <th>-0.6190</th>
#     <th>0.5212</th>
#     <th>-0.0222</th>
#     <th>0.8315</th>
#     <th>1.0291</th>
#     <th>2.7626</th>
#     <th>-0.3230</th>
#     <th>-0.8633</th>
#     <th>-0.3489</th>
#     <th>0.8253</th>
#     <th>-0.3155</th>
#     <th>2.1856</th>
#     <th>0.1148</th>
#     <th>-0.0264</th>
#     <th>-2.1765</th>
#     <th>0.9414</th>
#     <th>-0.7513</th>
#     <th>-0.5740</th>
#     <th>-0.4158</th>
#     <th>0.2402</th>
#     <th>1.4044</th>
#     <th>0.1322</th>
#     <th>-0.8017</th>
#     <th>0.1968</th>
#     <th>0.6768</th>
#     <th>0.0532</th>
#     <th>1.1297</th>
#     <th>-0.5673</th>
#     <th>rp16</th>
#   </tr>
#   <tr>
#     <th>True</th>
#     <th>0.1744</th>
#     <th>0.4623</th>
#     <th>-0.3396</th>
#     <th>0.3069</th>
#     <th>0.2792</th>
#     <th>2.2700</th>
#     <th>0.3869</th>
#     <th>-0.8336</th>
#     <th>0.4955</th>
#     <th>-0.4298</th>
#     <th>0.5961</th>
#     <th>0.2407</th>

# %%
learn = tabular_learner(data, layers=[200,100], metrics=accuracy)
learn.fit(1, 1e-2)
# Out:
# Total time: 00:01
# epoch  train_loss  valid_loss  accuracy
# 1      0.042732    nan         0.997159  (00:01)

# %% [markdown]
# ## Inference

# %%
row = df.iloc[9]
row
# Out:
# srs_1                  96
# srs_2                  98
# srs_3                 155
# srs_4                 143
# srs_5                  97
# srs_6                 147
# srs_7                 102
# srs_8                  98
# srs_9                 131
# srs_10                101
# srs_11                 97
# srs_12                193
# srs_13                 96
# srs_14                 99
# srs_15                 99
# srs_16                125
# srs_17                 99
# srs_18                100
# srs_19                 97
# srs_20                 92
# srs_21                 98
# srs_22                 98
# srs_23                122
# srs_24                150
# srs_25                 99
# srs_26                100
# srs_27                106
# srs_28                100
# srs_29                 97
# srs_30                 98
# srs_31                 98
# srs_32                102
# ue_loc_1             rp12
# ue_loc_2    rp12:rp3:rp24
# cat_1                True
# Name: 9, dtype: object

# %%
learn.predict(row)
# Out:
# ('rp12',
#  tensor(2),
#  tensor([2.3758e-08, 1.0065e-07, 9.9999e-01, 4.4452e-06, 4.2907e-06, 1.7782e-07,
#          8.8846e-08, 9.4709e-08, 1.3592e-06]))
